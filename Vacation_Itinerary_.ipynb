# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.

vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID      City Country  Max Temp Current Description      Lat       Lng  \
# 0        0  Araguacu      BR     82.26     overcast clouds -12.9306  -49.8264
# 1        2    Nabire      ID     75.88     overcast clouds  -3.3667  135.4833
# 2        6   Vilhena      BR     77.22       broken clouds -12.7406  -60.1458
# 3        8     Kapaa      US     75.52          few clouds  22.0752 -159.3190
# 4       13   Rikitea      PF     75.27     overcast clouds -23.1203 -134.9692
#
#   Hotel Name
# 0   Araguaçu
# 1     Nabire
# 2    Vilhena
# 3     Kapaʻa
# 4    Rikitea

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# %%
# 4b. Display the figure
print(fig)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Britain dataframe
BR_vacation_df = vacation_df.loc[(vacation_df["Country"] == "BR")]
BR_vacation_df.dropna()
# Out:
#      City_ID                      City Country  Max Temp Current Description  \
# 0          0                  Araguacu      BR     82.26     overcast clouds
# 2          6                   Vilhena      BR     77.22       broken clouds
# 10        33                    Palmas      BR     84.07       broken clouds
# 14        49           Arraial Do Cabo      BR     76.96          few clouds
# 18        63                  Belmonte      BR     82.40       broken clouds
# 23        74                     Coxim      BR     87.03          light rain
# 44       143         Sao Joao Da Barra      BR     78.89       broken clouds
# 45       150             Alta Floresta      BR     84.02       broken clouds
# 55       179                   Itarema      BR     87.39    scattered clouds
# 58       186                  Aripuana      BR     75.76     overcast clouds
# 61       193                    Castro      BR     77.34       broken clouds
# 67       216        Ribas Do Rio Pardo      BR     88.45     overcast clouds
# 92       274                     Amapa      BR     81.97       broken clouds
# 95       280  Sao Jose Da Coroa Grande      BR     83.37          few clouds
# 110      327                  Itaituba      BR     84.36    scattered clouds
# 111      328                   Humaita      BR     78.24     overcast clouds
# 115      351                    Olinda      BR     87.53          few clouds
# 136      412                    Acarau      BR     87.30    scattered clouds
# 139      420             Correia Pinto      BR     76.66     overcast clouds
# 146      442    Sao Miguel Do Araguaia      BR     83.19     overcast clouds
# 153      464                Vila Velha      BR     76.95       broken clouds
# 158      471                  Alenquer      BR     88.14     overcast clouds
# 161      488                    Touros      BR     88.70     overcast clouds
# 179      549                 Caravelas      BR     79.54     overcast clouds
# 195      597                 Ibotirama      BR     87.15     overcast clouds
# 197      602                    Trairi      BR     86.72    scattered clouds
# 216      657                     Prado      BR     78.71     overcast clouds
# 231      690                  Paracuru      BR     87.82    scattered clouds
#
#          Lat      Lng                Hotel Name
# 0   -12.9306 -49.8264                  Araguaçu
# 2   -12.7406 -60.1458                   Vilhena
# 10  -10.2128 -48.3603                    Palmas
# 14  -22.9661 -42.0278           Arraial do Cabo
# 18  -15.8631 -38.8828                  Belmonte
# 23  -18.5067 -54.7600                     Coxim
# 44  -21.6403 -41.0511                   Grussaí
# 45   -9.8756 -56.0861             Alta Floresta
# 55   -2.9248 -39.9167                   Itarema
# 58   -9.1667 -60.6333                  Aripuanã
# 61  -24.7911 -50.0119                    Castro
# 67  -20.4431 -53.7592        Ribas do Rio Pardo
# 92    1.0000 -52.0000                 Teresinha
# 95   -8.8978 -35.1478  São José da Coroa Grande
# 110  -4.2761 -55.9836                  Itaituba
# 111  -7.5061 -63.0208          Humaitá District
# 115  -8.0089 -34.8553                    Olinda
# 136  -2.8856 -40.1200                    Acaraú
# 139 -27.5847 -50.3611             Correia Pinto
# 146 -13.2750 -50.1628    São Miguel do Araguaia
# 153 -20.3297 -40.2925                Vila Velha
# 158  -1.9417 -54.7383                  Alenquer
# 161  -5.1989 -35.4608                    Touros
# 179 -17.7125 -39.2481                 Caravelas
# 195 -12.1853 -43.2206                 Ibotirama
# 197  -3.2778 -39.2689                    Trairi
# 216 -17.3411 -39.2208                     Prado
# 231  -3.4100 -39.0306                  Paracuru

# %%
new_column_order = ["City_ID", "City", "Country", "Lat","Lng", "Max Temp", "Current Description"]

# %%
Brazil_vacation_df = BR_vacation_df[new_column_order]
Brazil_vacation_df
# Out:
#      City_ID                      City Country      Lat      Lng  Max Temp  \
# 0          0                  Araguacu      BR -12.9306 -49.8264     82.26
# 2          6                   Vilhena      BR -12.7406 -60.1458     77.22
# 10        33                    Palmas      BR -10.2128 -48.3603     84.07
# 14        49           Arraial Do Cabo      BR -22.9661 -42.0278     76.96
# 18        63                  Belmonte      BR -15.8631 -38.8828     82.40
# 23        74                     Coxim      BR -18.5067 -54.7600     87.03
# 44       143         Sao Joao Da Barra      BR -21.6403 -41.0511     78.89
# 45       150             Alta Floresta      BR  -9.8756 -56.0861     84.02
# 55       179                   Itarema      BR  -2.9248 -39.9167     87.39
# 58       186                  Aripuana      BR  -9.1667 -60.6333     75.76
# 61       193                    Castro      BR -24.7911 -50.0119     77.34
# 67       216        Ribas Do Rio Pardo      BR -20.4431 -53.7592     88.45
# 92       274                     Amapa      BR   1.0000 -52.0000     81.97
# 95       280  Sao Jose Da Coroa Grande      BR  -8.8978 -35.1478     83.37
# 110      327                  Itaituba      BR  -4.2761 -55.9836     84.36
# 111      328                   Humaita      BR  -7.5061 -63.0208     78.24
# 115      351                    Olinda      BR  -8.0089 -34.8553     87.53
# 136      412                    Acarau      BR  -2.8856 -40.1200     87.30
# 139      420             Correia Pinto      BR -27.5847 -50.3611     76.66
# 146      442    Sao Miguel Do Araguaia      BR -13.2750 -50.1628     83.19
# 153      464                Vila Velha      BR -20.3297 -40.2925     76.95
# 158      471                  Alenquer      BR  -1.9417 -54.7383     88.14
# 161      488                    Touros      BR  -5.1989 -35.4608     88.70
# 179      549                 Caravelas      BR -17.7125 -39.2481     79.54
# 195      597                 Ibotirama      BR -12.1853 -43.2206     87.15
# 197      602                    Trairi      BR  -3.2778 -39.2689     86.72
# 216      657                     Prado      BR -17.3411 -39.2208     78.71
# 231      690                  Paracuru      BR  -3.4100 -39.0306     87.82
#
#     Current Description
# 0       overcast clouds
# 2         broken clouds
# 10        broken clouds
# 14           few clouds
# 18        broken clouds
# 23           light rain
# 44        broken clouds
# 45        broken clouds
# 55     scattered clouds
# 58      overcast clouds
# 61        broken clouds
# 67      overcast clouds
# 92        broken clouds
# 95           few clouds
# 110    scattered clouds
# 111     overcast clouds
# 115          few clouds
# 136    scattered clouds
# 139     overcast clouds
# 146     overcast clouds
# 153       broken clouds
# 158     overcast clouds
# 161     overcast clouds
# 179     overcast clouds
# 195     overcast clouds
# 197    scattered clouds
# 216     overcast clouds
# 231    scattered clouds

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
start = float(input("What is your Starting City_ID from BR List you would like for your trip? "))
stop1 = float(input("What is your First Stop City_ID from BR List you would like for your trip? "))
stop2 = float(input("What is your Second Stop City_ID from BR List you would like for your trip? "))
stop3 = float(input("What is your Thirth Stop City_ID from BR List you would like for your trip? "))
end = float(input("What is your Last City_ID from BR List you would like for your trip? "))
# Out:
# What is your Starting City_ID from BR List you would like for your trip? 33
# What is your First Stop City_ID from BR List you would like for your trip? 49
# What is your Second Stop City_ID from BR List you would like for your trip? 63
# What is your Thirth Stop City_ID from BR List you would like for your trip? 74
# What is your Last City_ID from BR List you would like for your trip? 143

# %%
vacation_start = BR_vacation_df.loc[(BR_vacation_df["City_ID"] == stop1)]
vacation_start = vacation_start.iloc[0]

vacation_stop1 = BR_vacation_df.loc[(BR_vacation_df["City_ID"] == stop2)]
vacation_stop1 = vacation_stop1.iloc[0]

vacation_stop2 = BR_vacation_df.loc[(BR_vacation_df["City_ID"] == stop3)]
vacation_stop2 = vacation_stop2.iloc[0]

vacation_stop3 = BR_vacation_df.loc[(BR_vacation_df["City_ID"] == end)]
vacation_stop3 = vacation_stop3.iloc[0]

vacation_end = BR_vacation_df.loc[(BR_vacation_df["City_ID"] <= end)]
vacation_end = vacation_end.iloc[0]

# %%
print("Your Starting Destination is " + vacation_start["City"] + ", " + vacation_start["Country"])
print("Your Frist Stop is " + vacation_stop1["City"] + ", " + vacation_stop1["Country"])
print("Your Second Stop is " + vacation_stop2["City"] + ", " + vacation_stop2["Country"])                                     
print("Your Thirth Stop is " + vacation_stop3["City"] + ", " + vacation_stop3["Country"])                                     
print("Your Last Stop in your vacation is " + vacation_end["City"] + ", " + vacation_end["Country"])
# Out:
# Your Starting Destination is Arraial Do Cabo, BR
# Your Frist Stop is Belmonte, BR
# Your Second Stop is Coxim, BR
# Your Thirth Stop is Sao Joao Da Barra, BR
# Your Last Stop in your vacation is Araguacu, BR

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[["Lat", "Lng"]]
print(start)
# Out:
# Lat   -22.9661
# Lng   -42.0278
# Name: 14, dtype: object

# %%
stop1 = vacation_stop1[["Lat", "Lng"]]
print(stop1)
# Out:
# Lat   -15.8631
# Lng   -38.8828
# Name: 18, dtype: object

# %%
stop2 = vacation_stop2[["Lat", "Lng"]]
print(stop2)
# Out:
# Lat   -18.5067
# Lng     -54.76
# Name: 23, dtype: object

# %%
stop3 = vacation_stop3[["Lat", "Lng"]]
print(stop3)
# Out:
# Lat   -21.6403
# Lng   -41.0511
# Name: 44, dtype: object

# %%
end = vacation_end[["Lat", "Lng"]]
print(end)
# Out:
# Lat   -12.9306
# Lng   -49.8264
# Name: 0, dtype: object

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)

start = (-21.6403, -41.0511)
stop1 = (-2.9248, -39.9167)
stop2 = ( -9.1667, -60.6333 )
stop3 = (-24.7911, -50.0119)
end = (-12.9306, -49.8264)

fig = gmaps.figure()
sart2end_via_stops = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(sart2end_via_stops)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
Brazil_vacation_df = pd.concat([Brazil_vacation_df],ignore_index=True)
Brazil_vacation_df
# Out:
#     City_ID                      City Country      Lat      Lng  Max Temp  \
# 0         0                  Araguacu      BR -12.9306 -49.8264     82.26
# 1         6                   Vilhena      BR -12.7406 -60.1458     77.22
# 2        33                    Palmas      BR -10.2128 -48.3603     84.07
# 3        49           Arraial Do Cabo      BR -22.9661 -42.0278     76.96
# 4        63                  Belmonte      BR -15.8631 -38.8828     82.40
# 5        74                     Coxim      BR -18.5067 -54.7600     87.03
# 6       143         Sao Joao Da Barra      BR -21.6403 -41.0511     78.89
# 7       150             Alta Floresta      BR  -9.8756 -56.0861     84.02
# 8       179                   Itarema      BR  -2.9248 -39.9167     87.39
# 9       186                  Aripuana      BR  -9.1667 -60.6333     75.76
# 10      193                    Castro      BR -24.7911 -50.0119     77.34
# 11      216        Ribas Do Rio Pardo      BR -20.4431 -53.7592     88.45
# 12      274                     Amapa      BR   1.0000 -52.0000     81.97
# 13      280  Sao Jose Da Coroa Grande      BR  -8.8978 -35.1478     83.37
# 14      327                  Itaituba      BR  -4.2761 -55.9836     84.36
# 15      328                   Humaita      BR  -7.5061 -63.0208     78.24
# 16      351                    Olinda      BR  -8.0089 -34.8553     87.53
# 17      412                    Acarau      BR  -2.8856 -40.1200     87.30
# 18      420             Correia Pinto      BR -27.5847 -50.3611     76.66
# 19      442    Sao Miguel Do Araguaia      BR -13.2750 -50.1628     83.19
# 20      464                Vila Velha      BR -20.3297 -40.2925     76.95
# 21      471                  Alenquer      BR  -1.9417 -54.7383     88.14
# 22      488                    Touros      BR  -5.1989 -35.4608     88.70
# 23      549                 Caravelas      BR -17.7125 -39.2481     79.54
# 24      597                 Ibotirama      BR -12.1853 -43.2206     87.15
# 25      602                    Trairi      BR  -3.2778 -39.2689     86.72
# 26      657                     Prado      BR -17.3411 -39.2208     78.71
# 27      690                  Paracuru      BR  -3.4100 -39.0306     87.82
#
#    Current Description
# 0      overcast clouds
# 1        broken clouds
# 2        broken clouds
# 3           few clouds
# 4        broken clouds
# 5           light rain
# 6        broken clouds
# 7        broken clouds
# 8     scattered clouds
# 9      overcast clouds
# 10       broken clouds
# 11     overcast clouds
# 12       broken clouds
# 13          few clouds
# 14    scattered clouds
# 15     overcast clouds
# 16          few clouds
# 17    scattered clouds
# 18     overcast clouds
# 19     overcast clouds
# 20       broken clouds
# 21     overcast clouds
# 22     overcast clouds
# 23     overcast clouds
# 24     overcast clouds
# 25    scattered clouds
# 26     overcast clouds
# 27    scattered clouds

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
mark_info = [info_box_template.format(**row) for index, row in Brazil_vacation_df.iterrows()]


# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = Brazil_vacation_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
city_mark = Brazil_vacation_df["City"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=mark_info)

fig.add_layer(marker_layer)

# %%
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
